# %% [markdown]
# # Varias cositas hoy + R + Markdown
#
# Hoy vamos a usar los .Rmd en R-Studio, los que están en la carpeta ./machine_learning_basics
#
# ## Binary Classification
#
# Todo modelo se puede reducir a clasificación Binaria... Osea una categoría es X o Otro. Osea, una multiclasificación puede ser una suma de varios modelos de clasificación binaria
#
# La idea es trazar una figura geométrica que DIVIDA LOS VALORES entre dos categorías...
#
# Sigo en el .Rmd

# %% [markdown]
# # PRACTICA!!!
#
#
# # 1. EXPLICAR EL BUSINESS CASE!
# # 2. Explicar bien el diccionario de datos tmb! --> Y HAY DOS!!!!!!!!!! EL RAW Y EL DE ENTRADA AL MODELO!!! (HACER!!!)
# # 3. VER MUY BIEN LO QUE VAMOS A HACER Y BUSCAR EN BASE A TODA LA INFO DE KAGGLE! Ver todo, PDF, Papers o lo que haga!
# ### 4. A LA HTML ES SOLO CUANDO ESTÁN ACABADOS!
# ### PASAR EL SWEETVIZ A REPORTS!
#
# # MATRIZ DE CONFUSIÓN EN UN SOLO CÓDIGO A FUNCIÓN!!!
#
# ## SIEMPRE CONCLUSIONES DE CADA ANÁLISIS! Mejores que los del EDA...
#
# # FEATURE ENGENEERING Y SELECCIÓN DE VARIABLES!!! CLAVE!!!
# Esto es: Genero variables nuevas en relación a lo que necesite!
#
# No por meter más info al modelo va a funcionar mejor!
#
# Modelos más simples mejores siempre obviamente...
#
# Un modelo más simple con Accuracy (x ej pq es una de tantas métricas) de 75% vs uno de 30 vars con acc del 80%, es mejor el primero!
#
# # MODELADO
# ### 1. MODELO BASE!!! --> NADA AL AZAR, A LA CLASE MAYORITARIA
# ### 2. DECISION TREE
# ### 3. NAIVE BAYES --> BUSCAR COMO HACER!
# ### 4. GLM --> INFORMARNOS Y VER QUE HACE... tiene que ver x el sumatorio de x por una función... MODELOS LINEALES GENERALIZADOS --> PONER EN EL NOTEBOOK
# https://christophm.github.io/interpretable-ml-book/extend-lm.html
# ### 5. SE PUEDE APLICAR GLM A ESTE CASO DE USO??? A clasificación! --> Si se puede, aplicarlo!!!
#
# # MÉTRICAS Y EVALUACIÓN DEL MODELO
# ### 1. Matriz de confució: valores absolutos y relativos!!!
# ### 2. Curva ROC
# ### 3. CURVA DE GANANCIA!!! --> Clave en casos de fraude!!!
# ### 4. Curva LIFT!
# # Esto es clave en el examen!
# ### 5. Adicionales: F1, Accuracy, Precision, Recall, ANALIZAR NUEVAS MÉTRICAS!!!
# ### TIEMPOS DE COMPUTO!
# # PREGUNTA A RESPONDER: CUAL ES LA MÉTRICA ADECUADA??? --> Puede ser una combinación de varias tmb
#
# # CUAL ES EL MEJOR MODELO??? --> Como los comparo???
#
#
# # carpeta SRC: AHÍ PONER LOS .PY!
#
# # PEP8 STANDARDS: SI O SI CUMPLIR CON ESTO!!!
#
# ***
#
# # BALANCEO DEL DATASET!!! HACER ALGO!!! --> OVERSAMPLING O UNDERSAMPLING! VER QUE HACER!!! Si se hace bien, se pueden hacer las 2, ver!!!
# # HACER ANTES DEL FEATURE ENGENEERING!!!
#
# # BALANCEAR EN BASE A LA VARIABLE TARGET!!!!!!!
# # HACER EL OVERSAMPLING EN TRAIN, EL TEST TIENE QUE ESTAR LIMPIO!
#
# EL TEST NO TIENE QUE SER TOCADO!!!
#
# ***
# # CROSS VALIDATION: Sobre el Train! HACERLO!!! hay 2 formas: RANDOM SEARCH Y GRID SEARCH... LAS DOS EN SKL!!! --> VER CUAL ES LA MÁS PESADA en computo computacional!
#
# Recordar que el modelo normalmente se ejecuta sobre todo el DataSet, por más que se divida en trainy test...
#
# ***
# # Cada semana un modelo nuevo!!! --> Hay que tener todo listo para montar los modelos cada jueves!
#
# ## 23 Nov: SVM!
# ## 30 Nov: Random Forest y XGBoost
# ## 07 Dic: Interpretabilidad! Explicabilidad! --> Para acá tenemos que tener todo el trabajo listo
# # 10 SE ENTREGA EL PROYECTO!
# #### Graphos --> importante, dsps de esto
# #### Algoritmos evolutivos --> Optimización
#
# ***
# # PRACTICA 3: ELEGIR ENTRE 2 COSAS! --> Se pueden hacer las 2 para Matrícula!
#
# # 1. FLASK PYTHON --> PONER EN PRODUCCIÓN UN MODELO!!! --> HACER UNA API! --> HACER SI O SI! -->MUCHA DOCUMENTACIÓN Y EJEMPLOS.
# # SERVIDOR WEB, PICKLE Y JSON, ESO ES LA BASE DE ESTO!
# ### VAMOS A HACERLO CON POSTMAN! --> HERRAMIENTA PARA INVOCAR APIs!
# ### GENERAR EL FLASK Y PROBAR CON EL POSTMAN QUE FUNCIONA --> Enviar valores, recibir
# ### Esa API SE PUEDE LEVANTAR EN LOCAL!!!
#
#
# # 2. Generalized Additive Model (GAM):
# ### EXPLICAR LOS GAM
# ### Como si tuviesemos que dar una clase! --> Ejemplo en Python con este DataSet!
#
# https://christophm.github.io/interpretable-ml-book/extend-lm.html
#
# # ESTA ES PARA DSPS DE NAVIDAD! -- Inicios de Enero
#
#
#
#
# # Examen es tipo Test, SOLO TEORÍA! Selección múltiple, hay que tener TODAS bien, sino no puntúa...
# # CALCULOS EN PAPEL Y CALCULADORA!!! --> GINI X EJEMPLO, PRECISION Y RECALL!
#
# # Si desapruebas vas a Julio...
#
#
# # 3. SIMULADOR:
#
# Dataset de Test con modelo en formato pickle o joblib
#
# ## Herramienta en donde, en base a todos los datos de entrada se le dio una probabilidad de fraude... ME PERMITA EDITAR LOS VALORES DE ENTRADA DE UNA INSTANCIA Y QUE AUTOMÁTICAMENTE SE ME DEVUELVA EL VALOR!
#
# Tengo que poder variar en un solo campo o más y que me muestre la predicción (probabilidad de fraude)!
#
# El curro obviamente ES EL DISEÑO DE LA INTERFAZ!
#
# Dash, Plotly y demás hay que usar!!!
